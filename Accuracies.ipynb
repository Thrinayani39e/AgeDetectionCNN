# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7ebc4cec-783e-4821-8de2-4724da450484" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7ebc4cec-783e-4821-8de2-4724da450484">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df = pd.read_excel(io.BytesIO(uploaded['Accuracy_Table.xlsx']))
df
# Out:
#             Classifier  Accuracy  Regressor  Accuracies
# 0         k-NN \n(k=5)   0.88880        NaN         NaN
# 1                  MLP   0.81290        NaN         NaN
# 2  SVM \n(lin_pol_rbf)   0.87170        NaN         NaN
# 3            SVM (Sig)   0.69920        NaN         NaN
# 4               D_Tree   0.89820        NaN         NaN
# 5                   NB   0.53320        NaN         NaN
# 6      Random \nForest   0.90454        NaN         NaN
# 7           Perceptron   0.82252        NaN         NaN

# %%
# X = ['k-NN','MLP','SVM (lin_pol_rbf)','SVM (Sig)','Decision_Tree','NB']
X = df["Classifier"]
Y = df["Accuracy"]


left = [1, 2, 3, 4, 5]
  

height = [10, 24, 36, 40, 5]
df.plot(x='Classifier',y='Accuracy',kind='line',color='red')
plt.show()

# %% [markdown]
# Conclusion: Based on the accuracies of all the classifiers, k-NN is giving us a high accuracy of 0.892 so we will consider this as our classification model

# %% [markdown]
# We are also planning to build a Regression model on "Total" values so that we can predict the total no. of cars to be bought/produced.

# %% [markdown]
# So if anyone has some features in mind for a new vehicle, they can enter those in the model and they'll be able to figure out how many vehicles are to be produced.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e76a4954-fd90-4889-a651-de4bfe530a90" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e76a4954-fd90-4889-a651-de4bfe530a90">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df2 = pd.read_excel(io.BytesIO(uploaded['Accuracy_Table2.xlsx']))
df2
# Out:
#                  Regressor  Accuracy
# 0        k-NN \nRegression    0.4097
# 1    Multiple \nRegression    0.8976
# 2       D_Tree\nRegression    0.6224
# 3  Polynomial \nRegression    0.0391
# 4       Linear\nRegression    0.0017

# %%
X = df2["Regressor"]
Y = df2["Accuracy"]


left = [1, 2, 3, 4, 5]
  

height = [10, 24, 36, 40, 5]
df2.plot(x='Regressor',y='Accuracy',kind='line',color='red')
plt.show()
