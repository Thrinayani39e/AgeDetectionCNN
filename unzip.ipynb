# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Unzipping datasets
# !unzip -uq "/content/drive/MyDrive/UTKFace.zip" -d "/content/drive/My Drive/UTKFace"

# %%
# !unzip -uq "/content/drive/MyDrive/Copy of facial-age.zip" -d "/content/drive/My Drive/facialimages"
